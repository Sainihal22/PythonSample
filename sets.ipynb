# %%
import pandas as pd

df = pd.read_csv("customers.csv")
df
# Out:
#    customer_id     name  age gender  spend       city
# 0          101      Sai   23      M  12000  Bangalore
# 1          102      Anu   29      F  18000  Hyderabad
# 2          103    Rahul   35      M  25000      Delhi
# 3          104    Meena   21      F   8000    Chennai
# 4          105    Nihal   25      M   8000  Hyderabad
# 5          106  Saurabh   29      M   8000  Hyderabad
# 6          107     Neha   21      M   8000  Hyderabad
# 7          108    Priya   33      M   8000  Hyderabad

# %%
age_numbers = df["age"]
print(age_numbers)
print(len(age_numbers))
# Out:
# 0    23
# 1    29
# 2    35
# 3    21
# 4    25
# 5    29
# 6    21
# 7    33
# Name: age, dtype: int64
# 8

# %%
age_numbers = set(age_numbers)
print(age_numbers)
print(len(age_numbers))
# Out:
# {33, 35, 21, 23, 25, 29}
# 6

# %%
list(df["city"])
# Out:
# ['Bangalore',
#  'Hyderabad',
#  'Delhi',
#  'Chennai',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad']
