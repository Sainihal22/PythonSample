# %%
# Pandas

# Python Library to handle structured data like tables

# %%
# Two Main Data structures.
# 1. Series : 1D (one column)
# 2. DataFrame : 2D (table)

# %%
import pandas as pd
s = pd.Series([10,20,30])
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
